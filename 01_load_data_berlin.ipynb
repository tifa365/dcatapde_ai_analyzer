# %% [markdown]
# # Import metadata from Datenregister Berlin

# %%
import pandas as pd

pd.options.mode.chained_assignment = None
pd.options.display.max_rows = 500
pd.options.display.max_seq_items = 500

import requests
from tqdm.notebook import tqdm
import json
import warnings
import time

warnings.simplefilter("ignore", category=(UserWarning, FutureWarning))

# %%
# Constants
CKAN_API_LINK = (
    "https://datenregister.berlin.de/api/3/action/current_package_list_with_resources"
)

DATA_PATH = "01_dcat_de_metadata.csv"

# %%
def get_full_package_list(limit=500, sleep=2):
    """Get full package list from CKAN API"""
    offset = 0
    frames = []
    while True:
        print(f"{offset} packages retrieved.")
        url = CKAN_API_LINK + f"?limit={limit}&offset={offset}"
        res = requests.get(url)
        data = json.loads(res.content)
        if data["result"] == []:
            break
        data = pd.DataFrame(pd.json_normalize(data["result"]))
        frames.append(data)
        offset += limit
        time.sleep(sleep)
    data = pd.concat(frames)
    data = data.reset_index(drop=True)
    return data

# %% [markdown]
# # Load data

# %%
# Retrieve metadata for all datasets from CKAN API.
df = get_full_package_list()
df.to_csv(DATA_PATH, index=False)
# Out:
# 0 packages retrieved.
# 500 packages retrieved.
# 1000 packages retrieved.
# 1500 packages retrieved.
# 2000 packages retrieved.
# 2500 packages retrieved.
# 3000 packages retrieved.
# 3500 packages retrieved.

# %%
print(
    f"We have {len(df):,.0f} datasets in the catalogue and {df.shape[1]} properties.\n"
)
display(df.info(memory_usage="deep"))
display(df.head())
# Out:
# We have 3,310 datasets in the catalogue and 54 properties.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3310 entries, 0 to 3309
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   author                        3310 non-null   object
#  1   author_email                  923 non-null    object
#  2   berlin_source                 3310 non-null   object
#  3   berlin_type                   3310 non-null   object
#  4   creator_user_id               3310 non-null   object
#  5   date_released                 3310 non-null   object
#  6   date_updated                  2880 non-null   object
#  7   geographical_coverage         3298 non-null   object
#  8   geographical_granularity      3297 non-null   object
#  9   id                            3310 non-null   object
#  10  isopen                        3310 non-null   bool
#  11  license_id                    3310 non-null   object
#  12  license_title                 3310 non-null   object
#  13  license_url                   3230 non-null   object
#  14  maintainer                    3310 non-null   object
#  15  maintainer_email              3310 non-null   object
#  16  metadata_created              3310 non-null   object
#  17  metadata_modified             3310 non-null   object
#  18  name                          3310 non-null   object
#  19  notes                         3310 non-null   object
#  20  num_resources                 3310 non-null   int64
#  21  num_tags                      3310 non-null   int64
#  22  owner_org                     3310 non-null   object
#  23  private                       3310 non-null   bool
#  24  state                         3310 non-null   object
#  25  temporal_coverage_from        1083 non-null   object
#  26  temporal_coverage_to          975 non-null    object
#  27  temporal_granularity          3299 non-null   object
#  28  title                         3310 non-null   object
#  29  type                          3310 non-null   object
#  30  url                           3240 non-null   object
#  31  version                       140 non-null    object
#  32  groups                        3310 non-null   object
#  33  resources                     3310 non-null   object
#  34  tags                          3310 non-null   object
#  35  relationships_as_subject      3310 non-null   object
#  36  relationships_as_object       3310 non-null   object
#  37  organization.id               3310 non-null   object
#  38  organization.name             3310 non-null   object
#  39  organization.title            3310 non-null   object
#  40  organization.type             3310 non-null   object
#  41  organization.description      3310 non-null   object
#  42  organization.image_url        3310 non-null   object
#  43  organization.created          3310 non-null   object
#  44  organization.is_organization  3310 non-null   bool
#  45  organization.approval_status  3310 non-null   object
#  46  organization.state            3310 non-null   object
#  47  attribution_text              2604 non-null   object
#  48  username                      1047 non-null   object
#  49  hvd_category                  21 non-null     object
#  50  preview_image                 650 non-null    object
#  51  sample_record                 21 non-null     object
#  52  extras                        2412 non-null   object
#  53  ressource_count               3310 non-null   int64
# dtypes: bool(3), int64(3), object(48)
# memory usage: 14.7 MB
# None
#                                               author  \
# 0  Senatsverwaltung für Arbeit, Soziales, Gleichs...
# 1                                             LAGeSo
# 2  Presse,- Öffentlichkeitsarbeit & Digitale Komm...
# 3             Industrie- und Handelskammer zu Berlin
# 4      VBB - Verkehrsverbund Berlin-Brandenburg GmbH
#
#                        author_email  berlin_source berlin_type  \
# 0  bildungszeit@senasgiva.berlin.de   simplesearch   datensatz
# 1        webmaster@lageso.berlin.de   simplesearch   datensatz
# 2          internet@ba-sz.berlin.de   simplesearch   datensatz
# 3                              None  api-gitaction   datensatz
# 4                              None        webform   datensatz
#
#                         creator_user_id date_released date_updated  \
# 0  50e8a594-1945-487e-b77e-3baa14f6a3c7    2015-10-19   2024-02-14
# 1  b1e7b5de-7dab-497a-ba76-867bf93f22b3    2015-07-22   2024-07-26
# 2  50e8a594-1945-487e-b77e-3baa14f6a3c7    2020-02-18   2024-08-02
# 3  caa908e5-339d-4411-a11d-b13eb8e17f0d    2023-03-10   2024-08-02
# 4  b136bb34-d39b-4be2-8dd7-8779c2d92fe6    2013-07-01   2024-08-01
#
#   geographical_coverage geographical_granularity  \
# 0                Berlin                   Berlin
# 1                Berlin                   Berlin
# 2   Steglitz-Zehlendorf                   Bezirk
# 3                Berlin          GPS-Koordinaten
# 4                Berlin          GPS-Koordinaten
#
#                                      id  ...  organization.is_organization  \
# 0  a6828125-ae95-404f-9fb0-52eb91302fd8  ...                          True
# 1  4bd75f18-20bf-45e9-af17-3bf03ab6dc58  ...                          True
# 2  ab9cc108-b6f1-4115-8169-68d9d793b484  ...                          True
# 3  52bb6a20-819d-49dc-bf75-58941f134e59  ...                          True
# 4  96643363-971f-43f9-b93e-e721c5b84872  ...                          True
#
#   organization.approval_status organization.state  \
# 0                     approved             active
# 1                     approved             active
# 2                     approved             active
# 3                     approved             active
# 4                     approved             active
#
#                               attribution_text       username hvd_category  \
# 0                                          NaN            NaN          NaN
# 1                                          NaN            NaN          NaN
# 2                                          NaN            NaN          NaN
# 3                                               Theresa Ewert          NaN
# 4  VBB Verkehrsverbund Berlin-Brandenburg GmbH            NaN
#
#   preview_image sample_record extras ressource_count
# 0           NaN           NaN    NaN               5
# 1           NaN           NaN    NaN               9
# 2           NaN           NaN    NaN               5
# 3           NaN           NaN    NaN               1
# 4                                NaN               1
#
# [5 rows x 54 columns]

# %% [markdown]
# # Examine resources

# %%
df["ressource_count"] = df.resources.apply(len)
print(
    f"Datasets have between {df.ressource_count.min()} and {df.ressource_count.max()} resources."
)
display(df.ressource_count.value_counts().sort_index())
# Out:
# Datasets have between 0 and 143 resources.
# ressource_count
# 0         1
# 1      1022
# 2       353
# 3       176
# 4       595
# 5      1034
# 6        64
# 7        21
# 8         2
# 9        31
# 11        2
# 12        2
# 13        2
# 14        1
# 15        1
# 18        1
# 44        1
# 143       1
# Name: count, dtype: int64

# %%
# Create dataframe from distributions.

results = []
for idx, row in df.iterrows():
    tmp = [pd.json_normalize(x) for x in row.resources]
    try:
        tmp = pd.concat(tmp)
    except Exception as e:
        print(f"Error at index {idx}: {e}")
        continue
    results.append(tmp)

dist = pd.concat(results)
dist.reset_index(drop=True, inplace=True)
# Out:
# Error at index 3121: No objects to concatenate

# %%
print(f"We have {len(dist):,.0f} ressources in the {len(df)} datasets.")
print()
display(dist.info())
display(dist.head())
# Out:
# We have 10,938 ressources in the 3310 datasets.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10938 entries, 0 to 10937
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   cache_last_updated         0 non-null      object
#  1   cache_url                  7 non-null      object
#  2   created                    10938 non-null  object
#  3   description                10938 non-null  object
#  4   format                     10938 non-null  object
#  5   hash                       10938 non-null  object
#  6   id                         10938 non-null  object
#  7   language                   928 non-null    object
#  8   last_modified              16 non-null     object
#  9   metadata_modified          10938 non-null  object
#  10  mimetype                   466 non-null    object
#  11  mimetype_inner             352 non-null    object
#  12  name                       9598 non-null   object
#  13  package_id                 10938 non-null  object
#  14  position                   10938 non-null  int64
#  15  resource_type              352 non-null    object
#  16  size                       274 non-null    object
#  17  state                      10938 non-null  object
#  18  url                        10938 non-null  object
#  19  url_type                   0 non-null      object
#  20  internal_function          8338 non-null   object
#  21  main                       8363 non-null   object
#  22  resource_locator_function  8365 non-null   object
#  23  resource_locator_protocol  8365 non-null   object
#  24  weight                     8338 non-null   object
#  25  resource_group_id          766 non-null    object
#  26  webstore_last_updated      1364 non-null   object
#  27  webstore_url               1364 non-null   object
#  28  apiurl                     12 non-null     object
#  29  Abteilung                  4 non-null      object
#  30  Landesstelle               1 non-null      object
# dtypes: int64(1), object(30)
# memory usage: 2.6+ MB
# None
#   cache_last_updated cache_url                     created  \
# 0               None      None  2024-08-03T00:28:38.320849
# 1               None      None  2024-08-03T00:28:38.320853
# 2               None      None  2024-08-03T00:28:38.320855
# 3               None      None  2024-08-03T00:28:38.320856
# 4               None      None  2024-08-03T00:28:38.320858
#
#                                          description format hash  \
# 0  Webseite von "Suche nach anerkannten Veranstal...   HTML
# 1  REST-API mit JSON-Ausgabe für "Suche nach aner...   JSON
# 2  REST-API mit XML-Ausgabe für "Suche nach anerk...    XML
# 3  REST-API mit Excel(XLS)-Ausgabe für "Suche nac...    XLS
# 4  REST-API mit CSV-Ausgabe für "Suche nach anerk...    CSV
#
#                                      id language last_modified  \
# 0  ccd6c622-8137-463f-b636-74e72c0787ca       de          None
# 1  8d32c8ba-c9ba-49e2-aa4c-e41f0a731835       de          None
# 2  11c644dc-d341-4c3e-acdf-e17101e943c7       de          None
# 3  b076df5d-dfa1-41a5-8371-091937957d88       de          None
# 4  4a5ea596-fbbc-4da8-a438-810c19bb0cc1       de          None
#
#             metadata_modified  ... main resource_locator_function  \
# 0  2024-08-03T00:28:38.290405  ...  NaN                       NaN
# 1  2024-08-03T00:28:38.290607  ...  NaN                       NaN
# 2  2024-08-03T00:28:38.290741  ...  NaN                       NaN
# 3  2024-08-03T00:28:38.290862  ...  NaN                       NaN
# 4  2024-08-03T00:28:38.290979  ...  NaN                       NaN
#
#   resource_locator_protocol weight  resource_group_id webstore_last_updated  \
# 0                       NaN    NaN                NaN                   NaN
# 1                       NaN    NaN                NaN                   NaN
# 2                       NaN    NaN                NaN                   NaN
# 3                       NaN    NaN                NaN                   NaN
# 4                       NaN    NaN                NaN                   NaN
#
#   webstore_url apiurl Abteilung Landesstelle
# 0          NaN    NaN       NaN          NaN
# 1          NaN    NaN       NaN          NaN
# 2          NaN    NaN       NaN          NaN
# 3          NaN    NaN       NaN          NaN
# 4          NaN    NaN       NaN          NaN
#
# [5 rows x 31 columns]
