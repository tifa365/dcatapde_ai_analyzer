# %% [markdown]
# # Analyze metadata semantically with an LLM 🤖
#
# This script retrieves a list of open government datasets from an online metadata API, filters them to keep only certain entries, and then uses an OpenAI language model to perform a semantic analysis of each dataset’s title and description. The analysis generates several scores (content, context, quality, and spatial), which are then combined with the original metadata. Finally, the script saves this enriched information to an Excel file, delivering an AI-driven summary of each dataset’s metadata. 🚀

# %%
# Auto reload modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Imports
import pandas as pd
import numpy as np

# Display a message to inform the user about the import process
print("Importing necessary libraries and setting options...")

pd.options.mode.chained_assignment = None
pd.options.display.max_rows = 500
pd.options.display.max_seq_items = 500

from datetime import datetime
from tqdm.notebook import tqdm
import requests
from concurrent.futures import ThreadPoolExecutor
from utils import do_full_analysis, parse_analysis_results
import warnings
import time
import json
import re

pd.options.mode.chained_assignment = None
pd.options.display.max_rows = 500
pd.options.display.max_seq_items = 500

warnings.simplefilter("ignore", category=(UserWarning, FutureWarning))
# Out:
# Importing necessary libraries and setting options...

# %%
# Sanity check whether the API key is set

import os
import openai

# Retrieve the API key from environment variables
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if OPENAI_API_KEY is None:
    raise ValueError("OPENAI_API_KEY is not set in the environment.")
else:
    print("API key is correctly set.")

# Initialize the OpenAI client with the API key
openai.api_key = OPENAI_API_KEY

# Example usage
OPENAI_SYSTEM_MESSAGE = "You are a helpful assistant."
# Out:
# API key is correctly set.

# %%
# Constants
# Dataset links are composed of this baselink and the identifier for each dataset.
BASELINK_DATASHOP = "https://daten.berlin.de/datensaetze/"

MDV_DATA_PATH = "_data/01_mdv_metadata.parq"

# Default figure size for Quarto HTML output.
FIGSIZE = (7, 5)

# Print output to inform the user about the constants being set
print("Constants have been defined:")
print(f"BASELINK_DATASHOP: {BASELINK_DATASHOP}")
print(f"MDV_DATA_PATH: {MDV_DATA_PATH}")
print(f"FIGSIZE: {FIGSIZE}")
# Out:
# Constants have been defined:
# BASELINK_DATASHOP: https://daten.berlin.de/datensaetze/
# MDV_DATA_PATH: _data/01_mdv_metadata.parq
# FIGSIZE: (7, 5)

# %% [markdown]
# In this notebook we perform a specific semantic analysis of titles and descriptions in our metadata catalog with LLMs.

# %% [markdown]
# ## Load data

# %% [markdown]
# ## Retrieve data from the metadata API.
#
# The code snippet you provided retrieves metadata from an API and expects the JSON response to contain a key named `"dataset"`. This key should map to a list of dataset entries, which can be normalized into a DataFrame using `pd.json_normalize`.
#
# ### Expected JSON Format
#
# The expected format of the JSON response from the API should look something like this:
#
# ```json
# {
#   "dataset": [
#     {
#       "identifier": "dataset1",
#       "title": "Dataset Title 1",
#       "description": "Description of dataset 1",
#       "publisher": {
#         "name": "Publisher Name"
#       },
#       "keyword": ["keyword1", "keyword2"]
#       // other fields...
#     },
#     {
#       "identifier": "dataset2",
#       "title": "Dataset Title 2",
#       "description": "Description of dataset 2",
#       "publisher": {
#         "name": "Publisher Name"
#       },
#       "keyword": ["keyword3", "keyword4"]
#       // other fields...
#     }
#     // more datasets...
#   ]
# }
# ```
#
# ### Key Points
#
# - The top-level key should be `"dataset"`, which contains an array of dataset objects.
# - Each dataset object should have fields like `"identifier"`, `"title"`, `"description"`, and `"publisher"`, among others.
# - The `pd.json_normalize` function will flatten nested structures, so if there are nested objects (like `"publisher"`), it will create separate columns for their fields.

# %%
# Constants
MDV_API_LINK = (
    "https://datenregister.berlin.de/api/3/action/current_package_list_with_resources"
)
DATA_PATH = "metadata.parquet"


def get_full_package_list(limit=500, sleep=2):
    """Get full package list from CKAN API"""
    offset = 0
    frames = []
    while True:
        print(f"{offset} packages retrieved.")
        url = MDV_API_LINK + f"?limit={limit}&offset={offset}"
        res = requests.get(url)
        data = res.json()
        if data["result"] == []:
            break
        data = pd.DataFrame(pd.json_normalize(data["result"]))
        frames.append(data)
        offset += limit
        time.sleep(sleep)

    data = pd.concat(frames)
    data = data.reset_index(drop=True)

    # Convert complex objects to strings for safe parquet storage
    object_cols = data.select_dtypes(include=["object"]).columns
    for col in object_cols:
        if data[col].notna().any() and isinstance(data[col].iloc[0], (list, dict)):
            data[col] = data[col].apply(json.dumps)

    return data


# Retrieve metadata for all datasets
df = get_full_package_list()

# Save to parquet
df.to_parquet(DATA_PATH)

# Print the path and file that was saved
print(f"Saved the dataset to: {DATA_PATH}")

# Give user some info about the datasets
print(
    f"We have {len(df):,.0f} datasets in the catalogue and {df.shape[1]} properties.\n"
)
display(df.info(memory_usage="deep"))
display(df.head())
# Out:
# 0 packages retrieved.
# 500 packages retrieved.
# 1000 packages retrieved.
# 1500 packages retrieved.
# 2000 packages retrieved.
# 2500 packages retrieved.
# 3000 packages retrieved.
# 3500 packages retrieved.
# Saved the dataset to: metadata.parquet
# We have 3,176 datasets in the catalogue and 53 properties.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3176 entries, 0 to 3175
# Data columns (total 53 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   author                        3176 non-null   object
#  1   author_email                  920 non-null    object
#  2   berlin_source                 3176 non-null   object
#  3   berlin_type                   3176 non-null   object
#  4   creator_user_id               3176 non-null   object
#  5   date_released                 3176 non-null   object
#  6   date_updated                  2736 non-null   object
#  7   geographical_coverage         3158 non-null   object
#  8   geographical_granularity      3157 non-null   object
#  9   id                            3176 non-null   object
#  10  isopen                        3176 non-null   bool
#  11  license_id                    3176 non-null   object
#  12  license_title                 3176 non-null   object
#  13  license_url                   3093 non-null   object
#  14  maintainer                    3176 non-null   object
#  15  maintainer_email              3176 non-null   object
#  16  metadata_created              3176 non-null   object
#  17  metadata_modified             3176 non-null   object
#  18  name                          3176 non-null   object
#  19  notes                         3176 non-null   object
#  20  num_resources                 3176 non-null   int64
#  21  num_tags                      3176 non-null   int64
#  22  owner_org                     3176 non-null   object
#  23  private                       3176 non-null   bool
#  24  state                         3176 non-null   object
#  25  temporal_coverage_from        1118 non-null   object
#  26  temporal_coverage_to          1006 non-null   object
#  27  temporal_granularity          3165 non-null   object
#  28  title                         3176 non-null   object
#  29  type                          3176 non-null   object
#  30  url                           2934 non-null   object
#  31  version                       140 non-null    object
#  32  groups                        3176 non-null   object
#  33  resources                     3176 non-null   object
#  34  tags                          3176 non-null   object
#  35  relationships_as_subject      3176 non-null   object
#  36  relationships_as_object       3176 non-null   object
#  37  organization.id               3176 non-null   object
#  38  organization.name             3176 non-null   object
#  39  organization.title            3176 non-null   object
#  40  organization.type             3176 non-null   object
#  41  organization.description      3176 non-null   object
#  42  organization.image_url        3176 non-null   object
#  43  organization.created          3176 non-null   object
#  44  organization.is_organization  3176 non-null   bool
#  45  organization.approval_status  3176 non-null   object
#  46  organization.state            3176 non-null   object
#  47  attribution_text              2473 non-null   object
#  48  username                      1036 non-null   object
#  49  preview_image                 1544 non-null   object
#  50  extras                        2236 non-null   object
#  51  hvd_category                  37 non-null     object
#  52  sample_record                 37 non-null     object
# dtypes: bool(3), int64(2), object(48)
# memory usage: 27.0 MB
# None
#                                               author  \
# 0  Senatsverwaltung für Arbeit, Soziales, Gleichs...
# 1             Industrie- und Handelskammer zu Berlin
# 2  Senatsverwaltung für Stadtentwicklung, Bauen u...
# 3  Senatsverwaltung für Stadtentwicklung, Bauen u...
# 4  Senatsverwaltung für Stadtentwicklung, Bauen u...
#
#                        author_email      berlin_source berlin_type  \
# 0  bildungszeit@senasgiva.berlin.de       simplesearch   datensatz
# 1                              None      api-gitaction   datensatz
# 2                              None  harvest-fisbroker   datensatz
# 3                              None  harvest-fisbroker   datensatz
# 4                              None  harvest-fisbroker   datensatz
#
#                         creator_user_id date_released date_updated  \
# 0  50e8a594-1945-487e-b77e-3baa14f6a3c7    2015-10-19   2024-08-23
# 1  caa908e5-339d-4411-a11d-b13eb8e17f0d    2023-03-10   2025-02-02
# 2  89a24728-2513-4292-a0e9-dd35daa49a20    1984-04-20   1984-04-20
# 3  89a24728-2513-4292-a0e9-dd35daa49a20    1984-04-20   1984-04-20
# 4  89a24728-2513-4292-a0e9-dd35daa49a20    1989-04-25   1989-04-25
#
#   geographical_coverage geographical_granularity  \
# 0                Berlin                   Berlin
# 1                Berlin          GPS-Koordinaten
# 2                Berlin                   Berlin
# 3                Berlin                   Berlin
# 4                Berlin                   Berlin
#
#                                      id  ...        organization.created  \
# 0  a6828125-ae95-404f-9fb0-52eb91302fd8  ...  2016-01-29T17:11:35.360140
# 1  52bb6a20-819d-49dc-bf75-58941f134e59  ...  2022-11-08T15:46:26.880719
# 2  72041737-d949-40a7-9bfb-cfc1b5fc472c  ...  2016-01-29T17:11:14.924180
# 3  e1fddb70-b70d-473c-b28d-9e4a551927cb  ...  2016-01-29T17:11:14.924180
# 4  6bd509b0-7184-4807-91a3-31faf02a8e42  ...  2016-01-29T17:11:14.924180
#
#   organization.is_organization organization.approval_status  \
# 0                         True                     approved
# 1                         True                     approved
# 2                         True                     approved
# 3                         True                     approved
# 4                         True                     approved
#
#   organization.state                            attribution_text  \
# 0             active                                         NaN
# 1             active
# 2             active  Geoportal Berlin / [Titel des Datensatzes]
# 3             active  Geoportal Berlin / [Titel des Datensatzes]
# 4             active  Geoportal Berlin / [Titel des Datensatzes]
#
#         username                                      preview_image  \
# 0            NaN                                                NaN
# 1  Theresa Ewert                                                NaN
# 2            NaN  https://fbinter.stadt-berlin.de/fb_daten/vorsc...
# 3            NaN  https://fbinter.stadt-berlin.de/fb_daten/vorsc...
# 4            NaN  https://fbinter.stadt-berlin.de/fb_daten/vorsc...
#
#                                               extras hvd_category  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2  [{'key': 'access_constraints', 'value': '["F\u...          NaN
# 3  [{'key': 'access_constraints', 'value': '["F\u...          NaN
# 4  [{'key': 'access_constraints', 'value': '["F\u...          NaN
#
#   sample_record
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 53 columns]

# %%
df.columns
# Out:
# Index(['author', 'author_email', 'berlin_source', 'berlin_type',
#        'creator_user_id', 'date_released', 'date_updated',
#        'geographical_coverage', 'geographical_granularity', 'id', 'isopen',
#        'license_id', 'license_title', 'license_url', 'maintainer',
#        'maintainer_email', 'metadata_created', 'metadata_modified', 'name',
#        'notes', 'num_resources', 'num_tags', 'owner_org', 'private', 'state',
#        'temporal_coverage_from', 'temporal_coverage_to',
#        'temporal_granularity', 'title', 'type', 'url', 'version', 'groups',
#        'resources', 'tags', 'relationships_as_subject',
#        'relationships_as_object', 'organization.id', 'organization.name',
#        'organization.title', 'organization.type', 'organization.description',
#        'organization.image_url', 'organization.created',
#        'organization.is_organization', 'organization.approval_status',
#        'organization.state', 'attribution_text', 'username', 'preview_image',
#        'extras', 'hvd_category', 'sample_record'],
#       dtype='object')

# %%
df[["title", "name", "notes"]].head(5)
# Out:
#                                        title  \
# 0     Suche nach anerkannten Veranstaltungen
# 1                Gewerbedaten der IHK Berlin
# 2   Luftbilder 1984, Maßstab 1:9 700 - [WFS]
# 3   Luftbilder 1984, Maßstab 1:9 700 - [WMS]
# 4  Luftbilder 1989, Maßstab 1:10 000 - [WFS]
#
#                                                 name  \
# 0  simple_search_wwwberlindesenarbeitweiterbildun...
# 1                             gewerbedaten-ihkberlin
# 2      luftbilder-1984-massstab-1-9-700-wfs-f9854f73
# 3      luftbilder-1984-massstab-1-9-700-wms-e7fe219c
# 4     luftbilder-1989-massstab-1-10-000-wfs-a410372b
#
#                                                notes
# 0  In Berlin anerkannte Weiterbildungsveranstaltu...
# 1  Der Datensatz beinhaltet die geografische Vert...
# 2  Luftbilder (Senkrechtaufnahmen) für das gesamt...
# 3  Luftbilder (Senkrechtaufnahmen) für das gesamt...
# 4  795 Schwarz/Weiß-Luftbilder (Senkrechtaufnahme...

# %%
# Load the dataset from a parquet file into a DataFrame
# df = pd.read_parquet(DATA_PATH)

# (Optional) Extract publisher information

# In the Zürich dataset, the publisher was extracted by splitting the 'identifier' field.
# However, Berlin’s CKAN metadata typically provides publisher information in a dedicated field,
# such as 'organization'. If your Berlin data includes this field, you can extract the publisher like so:
# if "organization" in df.columns:
#     # If 'organization' is a dictionary (as is common with CKAN), extract its title:
#     df["publisher"] = df["organization"].apply(
#         lambda org: org.get("title") if isinstance(org, dict) else org
#     )
# else:
#     print("No 'organization' field found; skipping publisher extraction.")

# (Optional) Filtering step: In the Zürich code, datasets were filtered to retain only those tagged as "ogd".

# In Berlin’s catalog (built on CKAN), all datasets are typically official Open Government Data.
# If you still need to filter (e.g., by a specific tag like "open-data"), adjust the lambda accordingly.
# if "tags" in df.columns:
#     # Example: filtering for datasets that include the term "open-data" in their tags
#     is_open_data = df.dropna(subset=["tags"]).tags.apply(
#         lambda x: "open-data" in x.lower()
#     )
#     df = df.loc[is_open_data[is_open_data].index]
# else:
#     print("No 'tags' column found; proceeding without tag-based filtering.")

# Reset the index of the DataFrame to ensure it is sequential after any filtering
# df.reset_index(drop=True, inplace=True)

# Check if the filtered DataFrame is empty; if so, raise an error; otherwise, print dataset count
# if len(df) == 0:
#     raise ValueError("No data retrieved.")
# else:
#     print(f"Retrieved {len(df)} datasets.")

# %% [markdown]
# ## Analyze and score metadata
#
# #
#
# # > **⚠️ Warning:** Processing a high number of datasets using an LLM might cost a bit of time and money. An alternative would be to use a batch API or use a local LLM. Please confer the docs of your LLM provider. Just a heads up!

# %%
# Be aware not to hit your OpenAI API rate limits with too many parallel requests.
n_parallel = 10

# Set a variable to specify the number of datasets to analyze. Default is None to process all datasets.
num_datasets_to_analyze = (
    10  # Change this value any number to None to process all datasets.
)

# Create a list of data rows to process in parallel, limited by the specified variable.
data_rows = [x[1] for x in list(df.iterrows())]

# If a number is specified, slice the data_rows; otherwise, use all datasets.
if num_datasets_to_analyze is not None:
    data_rows = data_rows[:num_datasets_to_analyze]

dataset_count = (
    num_datasets_to_analyze if num_datasets_to_analyze is not None else "all datasets"
)
print(
    f"Preparing to analyze {dataset_count} datasets in parallel with {n_parallel} workers."
)

# The analysis of the datasets will now begin using the specified number of parallel workers.
with ThreadPoolExecutor(max_workers=n_parallel) as executor:
    results = list(executor.map(do_full_analysis, data_rows))

# Print the LLM output for each dataset to check for empty XML responses
for i, result in enumerate(results):
    print(f"LLM output for dataset {i + 1}: {result}")

print("Analysis has been completed for all chosen datasets.")
# Out:
# Preparing to analyze 10 datasets in parallel with 10 workers.
# LLM output for dataset 1: ```xml
# <dateninhalt>Der Titel „Suche nach anerkannten Veranstaltungen“ ist sehr allgemein und gibt keinen spezifischen Hinweis darauf, welche Art von Veranstaltungen gemeint sind (z. B. berufliche Weiterbildung, Seminare, Workshops etc.). Die Beschreibung „In Berlin anerkannte Weiterbildungsveranstaltungen“ ist ebenfalls vage und lässt offen, welche Kriterien für die Anerkennung gelten und ob es sich um bestimmte Themen oder Zielgruppen handelt. Insgesamt fehlen detaillierte Informationen zu den Inhalten der Veranstaltungen, was die Aussagekraft des Datensatzes stark einschränkt.</dateninhalt>
# <methodik>Es wird nicht erklärt, wie die Daten erfasst wurden, welche Kriterien zur Anerkennung der Veranstaltungen führen und ob es eine spezifische Quelle für diese Informationen gibt. Es fehlen jegliche Hinweise auf die Methodik der Datenerhebung oder die Datenquelle, was die Nachvollziehbarkeit der Daten stark beeinträchtigt.</methodik>
# <datenqualität>Es gibt keine Informationen zur Qualität der Daten oder zur Vollständigkeit. Es wird nicht erwähnt, ob die Daten regelmäßig aktualisiert werden oder ob es Änderungen in der Erhebung gab. Dies lässt Zweifel an der Verlässlichkeit des Datensatzes aufkommen.</datenqualität>
# <geographie>Die geographische Eingrenzung auf „Berlin“ ist vorhanden, jedoch wird nicht spezifiziert, ob sich die Veranstaltungen auf bestimmte Bezirke oder Stadtteile beziehen. Es fehlen detaillierte Informationen zur geographischen Abgrenzung der Daten, was ihre Anwendbarkeit einschränkt.</geographie>
#
# <dateninhalt-score>2</dateninhalt-score>
# <methodik-score>1</methodik-score>
# <datenqualität-score>1</datenqualität-score>
# <geographie-score>3</geographie-score>
# ```
# LLM output for dataset 2: <dateninhalt>Der Titel "Gewerbedaten der IHK Berlin" ist klar und beschreibt den Inhalt des Datensatzes, der die geografische Verteilung der gewerbetreibenden Unternehmen in Berlin umfasst. Die Beschreibung liefert detaillierte Informationen zu den Kategorien, nach denen die Unternehmen klassifiziert sind (Branche, Beschäftigtenklasse, Alter des Unternehmens, Rechtsform). Insgesamt sind die Informationen präzise und verständlich, jedoch könnte eine weitere Erläuterung der verwendeten Begriffe (wie z.B. "Beschäftigtenklasse") hilfreich sein. -> 4 Punkte</dateninhalt>
# <methodik>Die Methodik ist teilweise klar, da erwähnt wird, dass die Daten von der IHK erfasst werden und monatlich aktualisiert werden. Allerdings fehlt eine detaillierte Erklärung, wie die Daten genau erfasst werden und welche spezifischen Methoden angewendet werden. Die Erwähnung des GitHub-Repositories als Quelle ist positiv, jedoch sollte der Zugang zu diesem Repository und die dort enthaltenen Informationen genauer beschrieben werden. -> 3 Punkte</methodik>
# <datenqualität>Die Beschreibung deutet darauf hin, dass die Daten regelmäßig aktualisiert werden, was auf eine gewisse Datenqualität hindeutet. Allerdings fehlen spezifische Informationen zur Vollständigkeit der Daten oder zu möglichen Änderungen in der Erhebung. Eine genauere Beschreibung der Datenqualität und etwaiger Limitierungen wäre wünschenswert. -> 3 Punkte</datenqualität>
# <geographie>Die geographische Dimension ist gut beschrieben, da die Daten explizit auf die geografische Verteilung in Berlin eingehen und die Auflösung nach Lebensweltlich orientierten Räumen (LOR) angibt. Dies gibt einen klaren räumlichen Bezug. Dennoch könnte eine genauere Definition der "Lebensweltlich orientierten Räume" hilfreich sein, um die geographische Relevanz weiter zu verdeutlichen. -> 4 Punkte</geographie>
#
# <dateninhalt-score>4</dateninhalt-score>
# <methodik-score>3</methodik-score>
# <datenqualität-score>3</datenqualität-score>
# <geographie-score>4</geographie-score>
# LLM output for dataset 3: <dateninhalt> Der Titel und die Beschreibung geben an, dass es sich um Luftbilder aus dem Jahr 1984 handelt, die das gesamte West-Berliner Stadtgebiet abdecken. Allerdings fehlen spezifische Informationen über den Inhalt der Luftbilder, wie z.B. die Art der Informationen, die aus diesen Bildern gewonnen werden können (z.B. Bebauung, Vegetation). Daher ist die Erklärung nicht vollständig. </dateninhalt>
# <methodik> Es wird nicht erklärt, wie die Luftbilder erfasst wurden, welche Technologien oder Verfahren verwendet wurden und ob es spezifische Datenquellen gibt. Auch die Bedeutung der Abkürzung "WFS" (Web Feature Service) wird nicht erläutert, was die Verständlichkeit einschränkt. </methodik>
# <datenqualität> Es gibt keine Informationen zur Qualität der Daten, zur Vollständigkeit oder zu möglichen Einschränkungen bei der Erhebung der Luftbilder. Es wird nicht erwähnt, ob es Änderungen oder Besonderheiten bei der Datenerhebung gibt. </datenqualität>
# <geographie> Die Beschreibung erwähnt, dass die Luftbilder das gesamte West-Berliner Stadtgebiet abdecken, jedoch fehlen genauere geographische Angaben oder Grenzen. Es wird nicht spezifiziert, ob es sich um historische oder aktuelle Grenzen handelt. </geographie>
#
# <dateninhalt-score> 3 </dateninhalt-score>
# <methodik-score> 1 </methodik-score>
# <datenqualität-score> 1 </datenqualität-score>
# <geographie-score> 3 </geographie-score>
# LLM output for dataset 4: ```xml
# <dateninhalt>Der Titel und die Beschreibung geben an, dass es sich um Luftbilder aus dem Jahr 1984 handelt, die im Maßstab 1:9.700 für das gesamte West-Berliner Stadtgebiet vorliegen. Allerdings fehlt eine detaillierte Erklärung, welche spezifischen Informationen die Luftbilder enthalten und welche Relevanz sie haben. Es wäre hilfreich, mehr über den Inhalt der Bilder und deren mögliche Anwendungen zu erfahren.</dateninhalt>
# <methodik>Die Beschreibung erwähnt nicht, wie die Luftbilder erstellt wurden, welche Technologien oder Methoden verwendet wurden oder welche spezifischen Quellen für die Daten verantwortlich sind. Es gibt keine Informationen über die Erhebungsmethodik oder die Bedingungen, unter denen die Bilder aufgenommen wurden.</methodik>
# <datenqualität>Es gibt keine Angaben zur Qualität der Luftbilder, wie z.B. Auflösung, Vollständigkeit oder mögliche Einschränkungen. Weder wird erwähnt, ob die Daten vollständig sind, noch ob es Änderungen in der Erhebung gab. Dies lässt die Qualität der Daten unklar.</datenqualität>
# <geographie>Die Beschreibung gibt an, dass die Luftbilder das gesamte West-Berliner Stadtgebiet abdecken, was eine klare geographische Zuordnung darstellt. Jedoch fehlen spezifische geographische Details oder Hinweise auf besondere geografische Merkmale innerhalb des Stadtgebiets.</geographie>
#
# <dateninhalt-score>2</dateninhalt-score>
# <methodik-score>1</methodik-score>
# <datenqualität-score>1</datenqualität-score>
# <geographie-score>3</geographie-score>
# ```
# LLM output for dataset 5: <dateninhalt>Der Titel und die Beschreibung geben einen klaren Überblick über den Inhalt des Datensatzes. Es wird deutlich, dass es sich um Luftbilder aus dem Jahr 1989 handelt, die das West-Berliner Stadtgebiet abdecken. Die Beschreibung enthält spezifische Details wie den Maßstab, die Anzahl der Bilder und technische Spezifikationen wie Auflösung und Überdeckungen. Allerdings könnte die Beschreibung noch spezifischer auf den Zweck oder die Anwendung der Luftbilder eingehen, um die Relevanz des Datensatzes besser zu verdeutlichen.</dateninhalt>
# <methodik>Die Methodik ist in der Beschreibung nur teilweise angesprochen. Es wird erwähnt, dass es sich um Senkrechtaufnahmen handelt, aber es fehlen Informationen darüber, wie die Bilder erfasst wurden, welche Technologien verwendet wurden und ob es spezifische Standards oder Protokolle für die Erhebung gibt. Die Quelle der Daten ist nicht klar angegeben. Daher ist die Methodik nicht ausreichend detailliert.</methodik>
# <datenqualität>Die Beschreibung enthält keine Informationen zur Qualität der Daten, wie z.B. die Vollständigkeit, mögliche Fehlerquellen oder die Validierung der Bilder. Es wird lediglich die technische Spezifikation der Luftbilder erwähnt, aber keine Hinweise auf Änderungen in der Erhebung oder zur allgemeinen Datenqualität. Das Fehlen solcher Informationen ist ein wesentlicher Nachteil.</datenqualität>
# <geographie>Die geographische Abdeckung ist klar angegeben, da die Luftbilder das gesamte West-Berliner Stadtgebiet abdecken. Allerdings fehlt eine genauere Beschreibung, wie diese geographischen Daten erfasst wurden oder ob es spezifische geographische Grenzen gibt. Es wird nur allgemein auf West-Berlin verwiesen, was etwas vage bleibt.</geographie>
#
# <dateninhalt-score>4</dateninhalt-score>
# <methodik-score>2</methodik-score>
# <datenqualität-score>1</datenqualität-score>
# <geographie-score>3</geographie-score>
# LLM output for dataset 6: <dateninhalt>Der Titel und die Beschreibung geben an, dass es sich um eine Karte des zu erwartenden höchsten Grundwasserstands handelt, jedoch fehlen spezifische Details zu den dargestellten Daten. Es wird nicht klar, welche Zeiträume oder Messmethoden verwendet wurden, um diese Informationen zu erhalten. Der Titel könnte spezifischer sein, um die Art der Daten (z.B. Messwerte, Prognosen) deutlicher zu machen. -> 3 Punkte</dateninhalt>
# <methodik>Die Beschreibung enthält keine Informationen darüber, wie die Daten erfasst oder gemessen wurden. Es wird lediglich erwähnt, dass die Daten "witterungsbedingt" sind, jedoch bleibt unklar, welche Methoden zur Erhebung oder Berechnung verwendet wurden. Auch die Quelle der Daten wird nicht genannt. -> 1 Punkt</methodik>
# <datenqualität>Es gibt keine Angaben zur Qualität der Daten, zur Vollständigkeit oder zu möglichen Änderungen in der Erhebung. Es wird nicht erklärt, wie zuverlässig die Daten sind oder ob es Einschränkungen gibt. -> 1 Punkt</datenqualität>
# <geographie>Die geographische Abdeckung wird in der Beschreibung genannt (Hauptgrundwasserleiter, Teltow-Hochfläche, östlicher Teil der Barnim-Hochfläche, Panketalgrundwasserleiter), jedoch fehlen spezifische Koordinaten oder Kartenreferenzen, die eine genauere geographische Einordnung ermöglichen würden. -> 3 Punkte</geographie>
#
# <dateninhalt-score>3</dateninhalt-score>
# <methodik-score>1</methodik-score>
# <datenqualität-score>1</datenqualität-score>
# <geographie-score>3</geographie-score>
# LLM output for dataset 7: <dateninhalt>Der Titel und die Beschreibung geben an, dass es sich um Sachdaten zu Kohlenstoffvorräten der Vegetation in Berlin handelt, die auf Block- und Teilblockflächen bezogen sind. Die Angabe, dass die Daten in kg C/m² gemessen werden, ist hilfreich, aber es fehlt eine detaillierte Erklärung darüber, was genau unter "Block- und Teilblockflächen" verstanden wird und wie diese definiert sind. Auch eine Erläuterung zur Bedeutung der Kohlenstoffvorräte für die Umwelt und deren Relevanz wäre wünschenswert.</dateninhalt>
# <methodik>Die Beschreibung erwähnt, dass die Daten ein Teilergebnis des FE-Vorhabens NatKos der HU Berlin sind, jedoch fehlen spezifische Informationen darüber, wie die Daten erhoben wurden. Es wird nicht erklärt, welche Methoden oder Techniken verwendet wurden, um die Kohlenstoffvorräte zu messen. Die Quelle der Daten wird genannt, aber es fehlen Details zu den genauen Erhebungsverfahren.</methodik>
# <datenqualität>Es gibt keine Informationen zur Qualität der Daten, wie beispielsweise deren Vollständigkeit oder eventuelle Einschränkungen. Auch wird nicht auf Änderungen in der Erhebung oder mögliche Unsicherheiten hingewiesen. Dies ist ein wesentlicher Aspekt, der in der Beschreibung fehlt.</datenqualität>
# <geographie>Die geographische Abgrenzung ist klar, da die Daten sich auf Berlin beziehen, jedoch bleibt unklar, wie genau die Block- und Teilblockflächen definiert sind. Eine genauere Beschreibung, welche Gebiete oder spezifischen Flächen in Berlin erfasst werden, wäre hilfreich.</geographie>
#
# <dateninhalt-score>3</dateninhalt-score>
# <methodik-score>2</methodik-score>
# <datenqualität-score>1</datenqualität-score>
# <geographie-score>3</geographie-score>
# LLM output for dataset 8: <dateninhalt>Der Titel und die Beschreibung geben an, dass es um Kohlenstoffvorräte der oberirdischen Biomasse in Berlin geht. Die Daten beziehen sich auf Block- und Teilblockflächen sowie Straßenflächen. Es wird jedoch nicht näher erläutert, was genau unter "Kohlenstoffvorräten" zu verstehen ist und welche spezifischen Maße oder Einheiten verwendet werden. Die Beschreibung könnte detaillierter sein, um die Art der Daten und deren Relevanz besser zu erklären.</dateninhalt>
# <methodik>Die Beschreibung nennt, dass die Daten ein Teilergebnis des FE-Vorhabens NatKos der HU Berlin sind, jedoch fehlen spezifische Informationen darüber, wie die Daten gemessen wurden, welche Methoden verwendet wurden und welche Quellen konkret für die Datenerhebung herangezogen wurden. Auch Informationen über die Art der Erhebung (z. B. Feldmessungen, Satellitendaten) fehlen.</methodik>
# <datenqualität>Es wird erwähnt, dass die Daten im Rahmen eines geförderten Programms erstellt wurden, jedoch fehlen konkrete Informationen zur Qualität der Daten, wie z.B. die Vollständigkeit, die Validierung oder mögliche Unsicherheiten. Es gibt keine Hinweise auf Änderungen in der Datenerhebung oder auf die Aktualität der Daten.</datenqualität>
# <geographie>Die Beschreibung nennt spezifisch, dass die Daten für Berlin gelten, was positiv ist. Allerdings fehlen genauere Informationen darüber, welche geographischen Grenzen oder spezifischen Gebiete innerhalb Berlins betrachtet werden. Der Verweis auf "Block- und Teilblockfläche" könnte klarer definiert werden.</geographie>
#
# <dateninhalt-score>3</dateninhalt-score>
# <methodik-score>2</methodik-score>
# <datenqualität-score>1</datenqualität-score>
# <geographie-score>3</geographie-score>
# LLM output for dataset 9: <dateninhalt>Der Titel und die Beschreibung geben an, dass es sich um eine Grundwassergleichenkarte handelt, die den zu erwartenden mittleren höchsten Grundwasserstand darstellt. Jedoch fehlt eine detaillierte Erklärung, was genau die Grundwassergleichenkarte umfasst und welche spezifischen Daten darin enthalten sind. Die Beschreibung könnte klarer formuliert werden, um den Inhalt des Datensatzes besser zu verdeutlichen.</dateninhalt>
# <methodik>Die Beschreibung gibt an, dass es sich um einen Mittelwert der Jahreshöchstwerte handelt, jedoch fehlen spezifische Informationen darüber, wie die Daten gemessen wurden und welche Methodik zur Erhebung verwendet wurde. Es wird nicht erwähnt, ob und wo die Datenherkunft dokumentiert ist. Die Erwähnung von "keine künstlichen Eingriffen" ist vage und könnte mehr Kontext benötigen.</methodik>
# <datenqualität>Es gibt keine Informationen zur Qualität der Daten oder zur Vollständigkeit der Daten. Es wird nicht erläutert, ob es Änderungen in der Erhebung gab oder wie die Daten validiert wurden. Dies lässt Fragen zur Verlässlichkeit der Daten offen.</datenqualität>
# <geographie>Die geographische Reichweite wird erwähnt (Urstromtal und Panketal), jedoch bleibt unklar, wie genau diese Gebiete definiert sind und ob es spezifische Koordinaten oder Karten gibt, die den räumlichen Bezug verdeutlichen. Eine genauere geographische Beschreibung wäre hilfreich.</geographie>
#
# <dateninhalt-score>3</dateninhalt-score>
# <methodik-score>2</methodik-score>
# <datenqualität-score>1</datenqualität-score>
# <geographie-score>3</geographie-score>
# LLM output for dataset 10: <dateninhalt> Der Titel und die Beschreibung geben an, dass es sich um eine Darstellung von Begräbnisplätzen handelt, die für Opfer von Krieg und Gewaltherrschaft relevant sind und in Berlin liegen. Allerdings fehlen spezifische Details zu den erfassten Daten, wie z.B. die Anzahl der Begräbnisplätze, deren spezifische Standorte oder weitere relevante Informationen zu den Opfern. Der Titel enthält zudem die Abkürzung "[WMS]", die nicht erklärt wird und unklar bleibt. Insgesamt ist die Erklärung unzureichend. </dateninhalt>
# <methodik> Es wird nicht erklärt, wie die Daten erhoben oder gemessen wurden. Es fehlen Informationen zu den Quellen der Daten und wie die Zuordnung zu den Begräbnisplätzen erfolgt ist. Dies lässt die Methodik unklar und unvollständig erscheinen. </methodik>
# <datenqualität> Es gibt keine Informationen zur Qualität der Daten, wie z.B. zur Vollständigkeit oder zur Validität der Informationen. Auch Änderungen in der Erhebung oder deren Aktualität werden nicht angesprochen. Dies lässt die Datenqualität sehr fraglich erscheinen. </datenqualität>
# <geographie> Die geographische Zuordnung wird klar angegeben, da die Begräbnisplätze in Berlin liegen. Allerdings fehlen spezifische Informationen zu den genauen Standorten oder Bezirken, was die geographische Klarheit einschränkt. </geographie>
#
# <dateninhalt-score> 2 </dateninhalt-score>
# <methodik-score> 1 </methodik-score>
# <datenqualität-score> 1 </datenqualität-score>
# <geographie-score> 3 </geographie-score>
# Analysis has been completed for all chosen datasets.

# %%
results
# Out:
# ['```xml\n<dateninhalt>Der Titel „Suche nach anerkannten Veranstaltungen“ ist sehr allgemein und gibt keinen spezifischen Hinweis darauf, welche Art von Veranstaltungen gemeint sind (z. B. berufliche Weiterbildung, Seminare, Workshops etc.). Die Beschreibung „In Berlin anerkannte Weiterbildungsveranstaltungen“ ist ebenfalls vage und lässt offen, welche Kriterien für die Anerkennung gelten und ob es sich um bestimmte Themen oder Zielgruppen handelt. Insgesamt fehlen detaillierte Informationen zu den Inhalten der Veranstaltungen, was die Aussagekraft des Datensatzes stark einschränkt.</dateninhalt>\n<methodik>Es wird nicht erklärt, wie die Daten erfasst wurden, welche Kriterien zur Anerkennung der Veranstaltungen führen und ob es eine spezifische Quelle für diese Informationen gibt. Es fehlen jegliche Hinweise auf die Methodik der Datenerhebung oder die Datenquelle, was die Nachvollziehbarkeit der Daten stark beeinträchtigt.</methodik>\n<datenqualität>Es gibt keine Informationen zur Qualität der Daten oder zur Vollständigkeit. Es wird nicht erwähnt, ob die Daten regelmäßig aktualisiert werden oder ob es Änderungen in der Erhebung gab. Dies lässt Zweifel an der Verlässlichkeit des Datensatzes aufkommen.</datenqualität>\n<geographie>Die geographische Eingrenzung auf „Berlin“ ist vorhanden, jedoch wird nicht spezifiziert, ob sich die Veranstaltungen auf bestimmte Bezirke oder Stadtteile beziehen. Es fehlen detaillierte Informationen zur geographischen Abgrenzung der Daten, was ihre Anwendbarkeit einschränkt.</geographie>\n\n<dateninhalt-score>2</dateninhalt-score>\n<methodik-score>1</methodik-score>\n<datenqualität-score>1</datenqualität-score>\n<geographie-score>3</geographie-score>\n```',
#  '<dateninhalt>Der Titel "Gewerbedaten der IHK Berlin" ist klar und beschreibt den Inhalt des Datensatzes, der die geografische Verteilung der gewerbetreibenden Unternehmen in Berlin umfasst. Die Beschreibung liefert detaillierte Informationen zu den Kategorien, nach denen die Unternehmen klassifiziert sind (Branche, Beschäftigtenklasse, Alter des Unternehmens, Rechtsform). Insgesamt sind die Informationen präzise und verständlich, jedoch könnte eine weitere Erläuterung der verwendeten Begriffe (wie z.B. "Beschäftigtenklasse") hilfreich sein. -> 4 Punkte</dateninhalt>\n<methodik>Die Methodik ist teilweise klar, da erwähnt wird, dass die Daten von der IHK erfasst werden und monatlich aktualisiert werden. Allerdings fehlt eine detaillierte Erklärung, wie die Daten genau erfasst werden und welche spezifischen Methoden angewendet werden. Die Erwähnung des GitHub-Repositories als Quelle ist positiv, jedoch sollte der Zugang zu diesem Repository und die dort enthaltenen Informationen genauer beschrieben werden. -> 3 Punkte</methodik>\n<datenqualität>Die Beschreibung deutet darauf hin, dass die Daten regelmäßig aktualisiert werden, was auf eine gewisse Datenqualität hindeutet. Allerdings fehlen spezifische Informationen zur Vollständigkeit der Daten oder zu möglichen Änderungen in der Erhebung. Eine genauere Beschreibung der Datenqualität und etwaiger Limitierungen wäre wünschenswert. -> 3 Punkte</datenqualität>\n<geographie>Die geographische Dimension ist gut beschrieben, da die Daten explizit auf die geografische Verteilung in Berlin eingehen und die Auflösung nach Lebensweltlich orientierten Räumen (LOR) angibt. Dies gibt einen klaren räumlichen Bezug. Dennoch könnte eine genauere Definition der "Lebensweltlich orientierten Räume" hilfreich sein, um die geographische Relevanz weiter zu verdeutlichen. -> 4 Punkte</geographie>\n\n<dateninhalt-score>4</dateninhalt-score>\n<methodik-score>3</methodik-score>\n<datenqualität-score>3</datenqualität-score>\n<geographie-score>4</geographie-score>',
#  '<dateninhalt> Der Titel und die Beschreibung geben an, dass es sich um Luftbilder aus dem Jahr 1984 handelt, die das gesamte West-Berliner Stadtgebiet abdecken. Allerdings fehlen spezifische Informationen über den Inhalt der Luftbilder, wie z.B. die Art der Informationen, die aus diesen Bildern gewonnen werden können (z.B. Bebauung, Vegetation). Daher ist die Erklärung nicht vollständig. </dateninhalt>\n<methodik> Es wird nicht erklärt, wie die Luftbilder erfasst wurden, welche Technologien oder Verfahren verwendet wurden und ob es spezifische Datenquellen gibt. Auch die Bedeutung der Abkürzung "WFS" (Web Feature Service) wird nicht erläutert, was die Verständlichkeit einschränkt. </methodik>\n<datenqualität> Es gibt keine Informationen zur Qualität der Daten, zur Vollständigkeit oder zu möglichen Einschränkungen bei der Erhebung der Luftbilder. Es wird nicht erwähnt, ob es Änderungen oder Besonderheiten bei der Datenerhebung gibt. </datenqualität>\n<geographie> Die Beschreibung erwähnt, dass die Luftbilder das gesamte West-Berliner Stadtgebiet abdecken, jedoch fehlen genauere geographische Angaben oder Grenzen. Es wird nicht spezifiziert, ob es sich um historische oder aktuelle Grenzen handelt. </geographie>\n\n<dateninhalt-score> 3 </dateninhalt-score>\n<methodik-score> 1 </methodik-score>\n<datenqualität-score> 1 </datenqualität-score>\n<geographie-score> 3 </geographie-score>',
#  '```xml\n<dateninhalt>Der Titel und die Beschreibung geben an, dass es sich um Luftbilder aus dem Jahr 1984 handelt, die im Maßstab 1:9.700 für das gesamte West-Berliner Stadtgebiet vorliegen. Allerdings fehlt eine detaillierte Erklärung, welche spezifischen Informationen die Luftbilder enthalten und welche Relevanz sie haben. Es wäre hilfreich, mehr über den Inhalt der Bilder und deren mögliche Anwendungen zu erfahren.</dateninhalt>\n<methodik>Die Beschreibung erwähnt nicht, wie die Luftbilder erstellt wurden, welche Technologien oder Methoden verwendet wurden oder welche spezifischen Quellen für die Daten verantwortlich sind. Es gibt keine Informationen über die Erhebungsmethodik oder die Bedingungen, unter denen die Bilder aufgenommen wurden.</methodik>\n<datenqualität>Es gibt keine Angaben zur Qualität der Luftbilder, wie z.B. Auflösung, Vollständigkeit oder mögliche Einschränkungen. Weder wird erwähnt, ob die Daten vollständig sind, noch ob es Änderungen in der Erhebung gab. Dies lässt die Qualität der Daten unklar.</datenqualität>\n<geographie>Die Beschreibung gibt an, dass die Luftbilder das gesamte West-Berliner Stadtgebiet abdecken, was eine klare geographische Zuordnung darstellt. Jedoch fehlen spezifische geographische Details oder Hinweise auf besondere geografische Merkmale innerhalb des Stadtgebiets.</geographie>\n\n<dateninhalt-score>2</dateninhalt-score>\n<methodik-score>1</methodik-score>\n<datenqualität-score>1</datenqualität-score>\n<geographie-score>3</geographie-score>\n```',
#  '<dateninhalt>Der Titel und die Beschreibung geben einen klaren Überblick über den Inhalt des Datensatzes. Es wird deutlich, dass es sich um Luftbilder aus dem Jahr 1989 handelt, die das West-Berliner Stadtgebiet abdecken. Die Beschreibung enthält spezifische Details wie den Maßstab, die Anzahl der Bilder und technische Spezifikationen wie Auflösung und Überdeckungen. Allerdings könnte die Beschreibung noch spezifischer auf den Zweck oder die Anwendung der Luftbilder eingehen, um die Relevanz des Datensatzes besser zu verdeutlichen.</dateninhalt>\n<methodik>Die Methodik ist in der Beschreibung nur teilweise angesprochen. Es wird erwähnt, dass es sich um Senkrechtaufnahmen handelt, aber es fehlen Informationen darüber, wie die Bilder erfasst wurden, welche Technologien verwendet wurden und ob es spezifische Standards oder Protokolle für die Erhebung gibt. Die Quelle der Daten ist nicht klar angegeben. Daher ist die Methodik nicht ausreichend detailliert.</methodik>\n<datenqualität>Die Beschreibung enthält keine Informationen zur Qualität der Daten, wie z.B. die Vollständigkeit, mögliche Fehlerquellen oder die Validierung der Bilder. Es wird lediglich die technische Spezifikation der Luftbilder erwähnt, aber keine Hinweise auf Änderungen in der Erhebung oder zur allgemeinen Datenqualität. Das Fehlen solcher Informationen ist ein wesentlicher Nachteil.</datenqualität>\n<geographie>Die geographische Abdeckung ist klar angegeben, da die Luftbilder das gesamte West-Berliner Stadtgebiet abdecken. Allerdings fehlt eine genauere Beschreibung, wie diese geographischen Daten erfasst wurden oder ob es spezifische geographische Grenzen gibt. Es wird nur allgemein auf West-Berlin verwiesen, was etwas vage bleibt.</geographie>\n\n<dateninhalt-score>4</dateninhalt-score>\n<methodik-score>2</methodik-score>\n<datenqualität-score>1</datenqualität-score>\n<geographie-score>3</geographie-score>',
#  '<dateninhalt>Der Titel und die Beschreibung geben an, dass es sich um eine Karte des zu erwartenden höchsten Grundwasserstands handelt, jedoch fehlen spezifische Details zu den dargestellten Daten. Es wird nicht klar, welche Zeiträume oder Messmethoden verwendet wurden, um diese Informationen zu erhalten. Der Titel könnte spezifischer sein, um die Art der Daten (z.B. Messwerte, Prognosen) deutlicher zu machen. -> 3 Punkte</dateninhalt>\n<methodik>Die Beschreibung enthält keine Informationen darüber, wie die Daten erfasst oder gemessen wurden. Es wird lediglich erwähnt, dass die Daten "witterungsbedingt" sind, jedoch bleibt unklar, welche Methoden zur Erhebung oder Berechnung verwendet wurden. Auch die Quelle der Daten wird nicht genannt. -> 1 Punkt</methodik>\n<datenqualität>Es gibt keine Angaben zur Qualität der Daten, zur Vollständigkeit oder zu möglichen Änderungen in der Erhebung. Es wird nicht erklärt, wie zuverlässig die Daten sind oder ob es Einschränkungen gibt. -> 1 Punkt</datenqualität>\n<geographie>Die geographische Abdeckung wird in der Beschreibung genannt (Hauptgrundwasserleiter, Teltow-Hochfläche, östlicher Teil der Barnim-Hochfläche, Panketalgrundwasserleiter), jedoch fehlen spezifische Koordinaten oder Kartenreferenzen, die eine genauere geographische Einordnung ermöglichen würden. -> 3 Punkte</geographie>\n\n<dateninhalt-score>3</dateninhalt-score>\n<methodik-score>1</methodik-score>\n<datenqualität-score>1</datenqualität-score>\n<geographie-score>3</geographie-score>',
#  '<dateninhalt>Der Titel und die Beschreibung geben an, dass es sich um Sachdaten zu Kohlenstoffvorräten der Vegetation in Berlin handelt, die auf Block- und Teilblockflächen bezogen sind. Die Angabe, dass die Daten in kg C/m² gemessen werden, ist hilfreich, aber es fehlt eine detaillierte Erklärung darüber, was genau unter "Block- und Teilblockflächen" verstanden wird und wie diese definiert sind. Auch eine Erläuterung zur Bedeutung der Kohlenstoffvorräte für die Umwelt und deren Relevanz wäre wünschenswert.</dateninhalt>\n<methodik>Die Beschreibung erwähnt, dass die Daten ein Teilergebnis des FE-Vorhabens NatKos der HU Berlin sind, jedoch fehlen spezifische Informationen darüber, wie die Daten erhoben wurden. Es wird nicht erklärt, welche Methoden oder Techniken verwendet wurden, um die Kohlenstoffvorräte zu messen. Die Quelle der Daten wird genannt, aber es fehlen Details zu den genauen Erhebungsverfahren.</methodik>\n<datenqualität>Es gibt keine Informationen zur Qualität der Daten, wie beispielsweise deren Vollständigkeit oder eventuelle Einschränkungen. Auch wird nicht auf Änderungen in der Erhebung oder mögliche Unsicherheiten hingewiesen. Dies ist ein wesentlicher Aspekt, der in der Beschreibung fehlt.</datenqualität>\n<geographie>Die geographische Abgrenzung ist klar, da die Daten sich auf Berlin beziehen, jedoch bleibt unklar, wie genau die Block- und Teilblockflächen definiert sind. Eine genauere Beschreibung, welche Gebiete oder spezifischen Flächen in Berlin erfasst werden, wäre hilfreich.</geographie>\n\n<dateninhalt-score>3</dateninhalt-score>\n<methodik-score>2</methodik-score>\n<datenqualität-score>1</datenqualität-score>\n<geographie-score>3</geographie-score>',
#  '<dateninhalt>Der Titel und die Beschreibung geben an, dass es um Kohlenstoffvorräte der oberirdischen Biomasse in Berlin geht. Die Daten beziehen sich auf Block- und Teilblockflächen sowie Straßenflächen. Es wird jedoch nicht näher erläutert, was genau unter "Kohlenstoffvorräten" zu verstehen ist und welche spezifischen Maße oder Einheiten verwendet werden. Die Beschreibung könnte detaillierter sein, um die Art der Daten und deren Relevanz besser zu erklären.</dateninhalt>\n<methodik>Die Beschreibung nennt, dass die Daten ein Teilergebnis des FE-Vorhabens NatKos der HU Berlin sind, jedoch fehlen spezifische Informationen darüber, wie die Daten gemessen wurden, welche Methoden verwendet wurden und welche Quellen konkret für die Datenerhebung herangezogen wurden. Auch Informationen über die Art der Erhebung (z. B. Feldmessungen, Satellitendaten) fehlen.</methodik>\n<datenqualität>Es wird erwähnt, dass die Daten im Rahmen eines geförderten Programms erstellt wurden, jedoch fehlen konkrete Informationen zur Qualität der Daten, wie z.B. die Vollständigkeit, die Validierung oder mögliche Unsicherheiten. Es gibt keine Hinweise auf Änderungen in der Datenerhebung oder auf die Aktualität der Daten.</datenqualität>\n<geographie>Die Beschreibung nennt spezifisch, dass die Daten für Berlin gelten, was positiv ist. Allerdings fehlen genauere Informationen darüber, welche geographischen Grenzen oder spezifischen Gebiete innerhalb Berlins betrachtet werden. Der Verweis auf "Block- und Teilblockfläche" könnte klarer definiert werden.</geographie>\n\n<dateninhalt-score>3</dateninhalt-score>\n<methodik-score>2</methodik-score>\n<datenqualität-score>1</datenqualität-score>\n<geographie-score>3</geographie-score>',
#  '<dateninhalt>Der Titel und die Beschreibung geben an, dass es sich um eine Grundwassergleichenkarte handelt, die den zu erwartenden mittleren höchsten Grundwasserstand darstellt. Jedoch fehlt eine detaillierte Erklärung, was genau die Grundwassergleichenkarte umfasst und welche spezifischen Daten darin enthalten sind. Die Beschreibung könnte klarer formuliert werden, um den Inhalt des Datensatzes besser zu verdeutlichen.</dateninhalt>\n<methodik>Die Beschreibung gibt an, dass es sich um einen Mittelwert der Jahreshöchstwerte handelt, jedoch fehlen spezifische Informationen darüber, wie die Daten gemessen wurden und welche Methodik zur Erhebung verwendet wurde. Es wird nicht erwähnt, ob und wo die Datenherkunft dokumentiert ist. Die Erwähnung von "keine künstlichen Eingriffen" ist vage und könnte mehr Kontext benötigen.</methodik>\n<datenqualität>Es gibt keine Informationen zur Qualität der Daten oder zur Vollständigkeit der Daten. Es wird nicht erläutert, ob es Änderungen in der Erhebung gab oder wie die Daten validiert wurden. Dies lässt Fragen zur Verlässlichkeit der Daten offen.</datenqualität>\n<geographie>Die geographische Reichweite wird erwähnt (Urstromtal und Panketal), jedoch bleibt unklar, wie genau diese Gebiete definiert sind und ob es spezifische Koordinaten oder Karten gibt, die den räumlichen Bezug verdeutlichen. Eine genauere geographische Beschreibung wäre hilfreich.</geographie>\n\n<dateninhalt-score>3</dateninhalt-score>\n<methodik-score>2</methodik-score>\n<datenqualität-score>1</datenqualität-score>\n<geographie-score>3</geographie-score>',
#  '<dateninhalt> Der Titel und die Beschreibung geben an, dass es sich um eine Darstellung von Begräbnisplätzen handelt, die für Opfer von Krieg und Gewaltherrschaft relevant sind und in Berlin liegen. Allerdings fehlen spezifische Details zu den erfassten Daten, wie z.B. die Anzahl der Begräbnisplätze, deren spezifische Standorte oder weitere relevante Informationen zu den Opfern. Der Titel enthält zudem die Abkürzung "[WMS]", die nicht erklärt wird und unklar bleibt. Insgesamt ist die Erklärung unzureichend. </dateninhalt>\n<methodik> Es wird nicht erklärt, wie die Daten erhoben oder gemessen wurden. Es fehlen Informationen zu den Quellen der Daten und wie die Zuordnung zu den Begräbnisplätzen erfolgt ist. Dies lässt die Methodik unklar und unvollständig erscheinen. </methodik>\n<datenqualität> Es gibt keine Informationen zur Qualität der Daten, wie z.B. zur Vollständigkeit oder zur Validität der Informationen. Auch Änderungen in der Erhebung oder deren Aktualität werden nicht angesprochen. Dies lässt die Datenqualität sehr fraglich erscheinen. </datenqualität>\n<geographie> Die geographische Zuordnung wird klar angegeben, da die Begräbnisplätze in Berlin liegen. Allerdings fehlen spezifische Informationen zu den genauen Standorten oder Bezirken, was die geographische Klarheit einschränkt. </geographie>\n\n<dateninhalt-score> 2 </dateninhalt-score>\n<methodik-score> 1 </methodik-score>\n<datenqualität-score> 1 </datenqualität-score>\n<geographie-score> 3 </geographie-score>']

# %%
# Perform a sanity check on the raw results to ensure all XML tags contain text content.
xml_columns = ["dateninhalt", "methodik", "datenqualität", "geographie"]
empty_tags = []

# Iterate over the raw results to check for empty XML tags
for i, result in enumerate(results):
    # Use regex to extract the content of each XML tag
    for tag in xml_columns:
        match = re.search(f"<{tag}>(.*?)</{tag}>", result, re.DOTALL)
        if not match or match.group(1).strip() == "":
            empty_tags.append((i, tag))

if empty_tags:
    for index, tag in empty_tags:
        print(
            f"Warning: The XML tag <{tag}> in dataset {index + 1} is empty. Please run the LLM analysis again."
        )
    print("Note: Running the analysis again may consume additional resources.")
else:
    print(
        "Sanity check passed: All XML tags with LLM-created content contain text content."
    )
# Out:
# Sanity check passed: All XML tags contain text content.

# %%
# Create a DataFrame from the results of the analysis, specifying the column name "results_raw".
# This DataFrame will hold the raw results returned from the LLM analysis for each dataset.
results_parsed = pd.DataFrame(results, columns=["results_raw"])

# Apply the function 'parse_analysis_results' to each entry in the "results_raw" column.
# This function is expected to process the raw results and extract meaningful information.
# Be cautious as this step may involve additional LLM calls, which can incur costs.
results_parsed = results_parsed["results_raw"].apply(parse_analysis_results)

# Concatenate the list of DataFrames returned by 'parse_analysis_results' into a single DataFrame.
# This is necessary because 'parse_analysis_results' may return a DataFrame for each row,
# and we need to combine them into one cohesive DataFrame.
results_parsed = pd.concat(results_parsed.tolist(), axis=0)

# Reset the index of the concatenated DataFrame to ensure it is sequential after concatenation.
# This helps maintain a clean DataFrame structure for further processing.
results_parsed.reset_index(drop=True, inplace=True)

# Combine the original DataFrame 'df' with the parsed results DataFrame 'results_parsed'.
# This creates a final DataFrame that includes both the original dataset information and the analysis results.
df_final = pd.concat([df, results_parsed], axis=1)

# Define a list of columns that we want to retain in the final output.
# These columns include identifiers and various scores that were generated during the analysis.
cols = [
    "id",
    "organization.title",
    "title",
    "notes",
    "content_score",
    "context_score",
    "quality_score",
    "spacial_score",
    "content",
    "context",
    "quality",
    "spacial",
]

# Generate a timestamp in the format YYYYMMDD to use in the filename for the output Excel file.
# This helps in organizing results by date.
timestamp = datetime.now().strftime("%Y%m%d")
df_final[cols].to_excel(f"../_results/metadata_analysis_{timestamp}.xlsx", index=False)
